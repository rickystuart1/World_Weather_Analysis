# %%
#import dependencies
import pandas as pd
import matplotlib as plt
import numpy as np
import time
from datetime import datetime

# %%
#create random coordinates 

lats = np.random.uniform(low = -90, high = 90, size = 2000)
lngs = np.random.uniform(low = -180, high = 180, size = 2000)
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 753

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
url = 'https://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=' + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather Description": description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | salalah
# Processing Record 3 of Set 1 | port elizabeth
# Processing Record 4 of Set 1 | barranca
# Processing Record 5 of Set 1 | veraval
# Processing Record 6 of Set 1 | arraial do cabo
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | upernavik
# Processing Record 9 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 1 | mogadishu
# Processing Record 11 of Set 1 | springbok
# Processing Record 12 of Set 1 | butaritari
# Processing Record 13 of Set 1 | evensk
# Processing Record 14 of Set 1 | tawnat
# City not found. Skipping...
# Processing Record 15 of Set 1 | atuona
# Processing Record 16 of Set 1 | byron bay
# Processing Record 17 of Set 1 | cape town
# Processing Record 18 of Set 1 | arkhangelsk
# Processing Record 19 of Set 1 | longyearbyen
# Processing Record 20 of Set 1 | kashi
# Processing Record 21 of Set 1 | wamba
# Processing Record 22 of Set 1 | hobart
# Processing Record 23 of Set 1 | provideniya
# Processing Record 24 of Set 1 | mataura
# Processing Record 25 of Set 1 | lata
# Processing Record 26 of Set 1 | port alfred
# Processing Record 27 of Set 1 | ostrovnoy
# Processing Record 28 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 29 of Set 1 | taoudenni
# Processing Record 30 of Set 1 | albany
# Processing Record 31 of Set 1 | puerto ayora
# Processing Record 32 of Set 1 | dwarka
# Processing Record 33 of Set 1 | azacualpa
# Processing Record 34 of Set 1 | rosamorada
# Processing Record 35 of Set 1 | saint-georges
# Processing Record 36 of Set 1 | grand gaube
# Processing Record 37 of Set 1 | bjornevatn
# Processing Record 38 of Set 1 | arrecife
# Processing Record 39 of Set 1 | aden
# Processing Record 40 of Set 1 | asyut
# Processing Record 41 of Set 1 | barrow
# Processing Record 42 of Set 1 | mar del plata
# Processing Record 43 of Set 1 | jamestown
# Processing Record 44 of Set 1 | sindor
# Processing Record 45 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 46 of Set 1 | xai-xai
# Processing Record 47 of Set 1 | souillac
# Processing Record 48 of Set 1 | kolkhikon
# City not found. Skipping...
# Processing Record 49 of Set 1 | levelland
# Processing Record 50 of Set 1 | napier
# Processing Record 1 of Set 2 | vanderhoof
# Processing Record 2 of Set 2 | ornskoldsvik
# Processing Record 3 of Set 2 | porto novo
# Processing Record 4 of Set 2 | saint george
# Processing Record 5 of Set 2 | esperance
# Processing Record 6 of Set 2 | nguiu
# City not found. Skipping...
# Processing Record 7 of Set 2 | saskylakh
# Processing Record 8 of Set 2 | hithadhoo
# Processing Record 9 of Set 2 | zarubino
# Processing Record 10 of Set 2 | pemangkat
# Processing Record 11 of Set 2 | vaini
# Processing Record 12 of Set 2 | rikitea
# Processing Record 13 of Set 2 | east london
# Processing Record 14 of Set 2 | san jeronimo
# Processing Record 15 of Set 2 | dikson
# Processing Record 16 of Set 2 | lavrentiya
# Processing Record 17 of Set 2 | erenhot
# Processing Record 18 of Set 2 | new norfolk
# Processing Record 19 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 20 of Set 2 | tiksi
# Processing Record 21 of Set 2 | camacha
# Processing Record 22 of Set 2 | tasiilaq
# Processing Record 23 of Set 2 | cache creek
# Processing Record 24 of Set 2 | mosetse
# Processing Record 25 of Set 2 | hilo
# Processing Record 26 of Set 2 | adrar
# Processing Record 27 of Set 2 | yellowknife
# Processing Record 28 of Set 2 | caravelas
# Processing Record 29 of Set 2 | coihaique
# Processing Record 30 of Set 2 | elhovo
# Processing Record 31 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 32 of Set 2 | hobyo
# Processing Record 33 of Set 2 | comodoro rivadavia
# Processing Record 34 of Set 2 | radcliff
# Processing Record 35 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 36 of Set 2 | aginskoye
# Processing Record 37 of Set 2 | kondinskoye
# Processing Record 38 of Set 2 | filadelfia
# Processing Record 39 of Set 2 | saint anthony
# Processing Record 40 of Set 2 | tuktoyaktuk
# Processing Record 41 of Set 2 | guerrero negro
# Processing Record 42 of Set 2 | venado tuerto
# Processing Record 43 of Set 2 | mahebourg
# Processing Record 44 of Set 2 | cap malheureux
# Processing Record 45 of Set 2 | kaitangata
# Processing Record 46 of Set 2 | kodiak
# Processing Record 47 of Set 2 | huaraz
# Processing Record 48 of Set 2 | ambilobe
# Processing Record 49 of Set 2 | chokurdakh
# Processing Record 50 of Set 2 | bredasdorp
# Processing Record 1 of Set 3 | ajdabiya
# Processing Record 2 of Set 3 | kapaa
# Processing Record 3 of Set 3 | georgetown
# Processing Record 4 of Set 3 | palmer
# Processing Record 5 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 6 of Set 3 | karratha
# Processing Record 7 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 8 of Set 3 | broken hill
# Processing Record 9 of Set 3 | sioux lookout
# Processing Record 10 of Set 3 | pokosnoye
# Processing Record 11 of Set 3 | bethel
# Processing Record 12 of Set 3 | ribeira grande
# Processing Record 13 of Set 3 | severo-kurilsk
# Processing Record 14 of Set 3 | sinnamary
# Processing Record 15 of Set 3 | totesti
# Processing Record 16 of Set 3 | artyk
# City not found. Skipping...
# Processing Record 17 of Set 3 | gushikawa
# Processing Record 18 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 19 of Set 3 | clyde river
# Processing Record 20 of Set 3 | chumikan
# Processing Record 21 of Set 3 | yumen
# Processing Record 22 of Set 3 | grand centre
# City not found. Skipping...
# Processing Record 23 of Set 3 | shelburne
# Processing Record 24 of Set 3 | arlit
# Processing Record 25 of Set 3 | canchungo
# Processing Record 26 of Set 3 | ilhabela
# Processing Record 27 of Set 3 | tanshui
# City not found. Skipping...
# Processing Record 28 of Set 3 | palu
# Processing Record 29 of Set 3 | turukhansk
# Processing Record 30 of Set 3 | bhind
# Processing Record 31 of Set 3 | morant bay
# Processing Record 32 of Set 3 | durusu
# Processing Record 33 of Set 3 | boyuibe
# Processing Record 34 of Set 3 | olafsvik
# Processing Record 35 of Set 3 | okha
# Processing Record 36 of Set 3 | avarua
# Processing Record 37 of Set 3 | touros
# Processing Record 38 of Set 3 | manavalakurichi
# Processing Record 39 of Set 3 | hermanus
# Processing Record 40 of Set 3 | victoria
# Processing Record 41 of Set 3 | lebu
# Processing Record 42 of Set 3 | saint-pierre
# Processing Record 43 of Set 3 | atambua
# Processing Record 44 of Set 3 | aksha
# Processing Record 45 of Set 3 | vellmar
# Processing Record 46 of Set 3 | kibala
# Processing Record 47 of Set 3 | bluff
# Processing Record 48 of Set 3 | castro
# Processing Record 49 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 50 of Set 3 | bonthe
# Processing Record 1 of Set 4 | carnarvon
# Processing Record 2 of Set 4 | dunyapur
# Processing Record 3 of Set 4 | manokwari
# Processing Record 4 of Set 4 | sibolga
# Processing Record 5 of Set 4 | jedrzejow
# Processing Record 6 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 7 of Set 4 | sangmelima
# Processing Record 8 of Set 4 | pitimbu
# Processing Record 9 of Set 4 | skjervoy
# Processing Record 10 of Set 4 | busselton
# Processing Record 11 of Set 4 | qaanaaq
# Processing Record 12 of Set 4 | san rafael del sur
# Processing Record 13 of Set 4 | kindu
# Processing Record 14 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 4 | pevek
# Processing Record 16 of Set 4 | fort saint john
# City not found. Skipping...
# Processing Record 17 of Set 4 | svetlaya
# Processing Record 18 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 19 of Set 4 | constitucion
# Processing Record 20 of Set 4 | mamallapuram
# Processing Record 21 of Set 4 | bandarbeyla
# Processing Record 22 of Set 4 | thompson
# Processing Record 23 of Set 4 | high level
# Processing Record 24 of Set 4 | mogochin
# City not found. Skipping...
# Processing Record 25 of Set 4 | barkhan
# Processing Record 26 of Set 4 | makakilo city
# Processing Record 27 of Set 4 | margate
# Processing Record 28 of Set 4 | natal
# Processing Record 29 of Set 4 | bengkulu
# Processing Record 30 of Set 4 | tessalit
# Processing Record 31 of Set 4 | tromso
# Processing Record 32 of Set 4 | hamilton
# Processing Record 33 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 34 of Set 4 | kismayo
# Processing Record 35 of Set 4 | alofi
# Processing Record 36 of Set 4 | tolaga bay
# Processing Record 37 of Set 4 | mattru
# Processing Record 38 of Set 4 | kandrian
# Processing Record 39 of Set 4 | dubbo
# Processing Record 40 of Set 4 | azul
# Processing Record 41 of Set 4 | lorengau
# Processing Record 42 of Set 4 | noumea
# Processing Record 43 of Set 4 | saldanha
# Processing Record 44 of Set 4 | ketchikan
# Processing Record 45 of Set 4 | aklavik
# Processing Record 46 of Set 4 | waingapu
# Processing Record 47 of Set 4 | christchurch
# Processing Record 48 of Set 4 | pampa
# Processing Record 49 of Set 4 | kalemie
# Processing Record 50 of Set 4 | andenes
# Processing Record 1 of Set 5 | porto santo
# Processing Record 2 of Set 5 | batemans bay
# Processing Record 3 of Set 5 | kolondieba
# Processing Record 4 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 5 | gazojak
# Processing Record 6 of Set 5 | alotau
# City not found. Skipping...
# Processing Record 7 of Set 5 | cabo san lucas
# Processing Record 8 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 9 of Set 5 | nikolskoye
# Processing Record 10 of Set 5 | pisco
# Processing Record 11 of Set 5 | fortuna
# Processing Record 12 of Set 5 | puerto baquerizo moreno
# Processing Record 13 of Set 5 | coquimbo
# Processing Record 14 of Set 5 | linchuan
# City not found. Skipping...
# Processing Record 15 of Set 5 | sisimiut
# Processing Record 16 of Set 5 | houston
# Processing Record 17 of Set 5 | syumsi
# Processing Record 18 of Set 5 | laguna
# Processing Record 19 of Set 5 | leningradskiy
# Processing Record 20 of Set 5 | mobaye
# Processing Record 21 of Set 5 | atyrau
# Processing Record 22 of Set 5 | dingle
# Processing Record 23 of Set 5 | velsk
# Processing Record 24 of Set 5 | jinxi
# Processing Record 25 of Set 5 | the valley
# Processing Record 26 of Set 5 | promyshlennaya
# Processing Record 27 of Set 5 | mingshui
# Processing Record 28 of Set 5 | hohhot
# Processing Record 29 of Set 5 | gangotri
# City not found. Skipping...
# Processing Record 30 of Set 5 | cortes
# Processing Record 31 of Set 5 | khandbari
# Processing Record 32 of Set 5 | vanimo
# Processing Record 33 of Set 5 | sayanogorsk
# Processing Record 34 of Set 5 | cherskiy
# Processing Record 35 of Set 5 | bayamo
# Processing Record 36 of Set 5 | hare bay
# Processing Record 37 of Set 5 | peniche
# Processing Record 38 of Set 5 | katsuura
# Processing Record 39 of Set 5 | ambagarh chauki
# Processing Record 40 of Set 5 | iranshahr
# Processing Record 41 of Set 5 | jodhpur
# Processing Record 42 of Set 5 | gananoque
# Processing Record 43 of Set 5 | maniitsoq
# Processing Record 44 of Set 5 | sahuaripa
# Processing Record 45 of Set 5 | herzogenburg
# Processing Record 46 of Set 5 | ferkessedougou
# Processing Record 47 of Set 5 | bartica
# Processing Record 48 of Set 5 | ancud
# Processing Record 49 of Set 5 | iquique
# Processing Record 50 of Set 5 | husavik
# Processing Record 1 of Set 6 | sola
# Processing Record 2 of Set 6 | ganzhou
# Processing Record 3 of Set 6 | narsaq
# Processing Record 4 of Set 6 | saint-philippe
# Processing Record 5 of Set 6 | meulaboh
# Processing Record 6 of Set 6 | domoni
# Processing Record 7 of Set 6 | ponta do sol
# Processing Record 8 of Set 6 | ryotsu
# Processing Record 9 of Set 6 | omsukchan
# Processing Record 10 of Set 6 | deloraine
# Processing Record 11 of Set 6 | hatsukaichi
# Processing Record 12 of Set 6 | hasaki
# Processing Record 13 of Set 6 | san patricio
# Processing Record 14 of Set 6 | bambous virieux
# Processing Record 15 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 16 of Set 6 | yaguajay
# Processing Record 17 of Set 6 | lazurne
# Processing Record 18 of Set 6 | mackay
# Processing Record 19 of Set 6 | sloboda
# Processing Record 20 of Set 6 | coahuayana
# Processing Record 21 of Set 6 | taseyevo
# Processing Record 22 of Set 6 | kyra
# Processing Record 23 of Set 6 | khatanga
# Processing Record 24 of Set 6 | haukipudas
# Processing Record 25 of Set 6 | tuatapere
# Processing Record 26 of Set 6 | tual
# Processing Record 27 of Set 6 | thinadhoo
# Processing Record 28 of Set 6 | kamarion
# Processing Record 29 of Set 6 | gazalkent
# Processing Record 30 of Set 6 | port lincoln
# Processing Record 31 of Set 6 | zemlyansk
# Processing Record 32 of Set 6 | khilok
# Processing Record 33 of Set 6 | beaune
# Processing Record 34 of Set 6 | bacolod
# Processing Record 35 of Set 6 | uray
# Processing Record 36 of Set 6 | isangel
# Processing Record 37 of Set 6 | grindavik
# Processing Record 38 of Set 6 | saint-augustin
# Processing Record 39 of Set 6 | shingu
# Processing Record 40 of Set 6 | klaksvik
# Processing Record 41 of Set 6 | huron
# Processing Record 42 of Set 6 | sainte-maxime
# Processing Record 43 of Set 6 | lugovoy
# Processing Record 44 of Set 6 | mount gambier
# Processing Record 45 of Set 6 | rodrigues alves
# Processing Record 46 of Set 6 | ahipara
# Processing Record 47 of Set 6 | taos
# Processing Record 48 of Set 6 | road town
# Processing Record 49 of Set 6 | razole
# Processing Record 50 of Set 6 | ambon
# Processing Record 1 of Set 7 | bethanien
# Processing Record 2 of Set 7 | aksu
# Processing Record 3 of Set 7 | gumushane
# City not found. Skipping...
# Processing Record 4 of Set 7 | buta
# Processing Record 5 of Set 7 | kruisfontein
# Processing Record 6 of Set 7 | mwinilunga
# Processing Record 7 of Set 7 | chuy
# Processing Record 8 of Set 7 | linxia
# Processing Record 9 of Set 7 | richards bay
# Processing Record 10 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 11 of Set 7 | shenjiamen
# Processing Record 12 of Set 7 | bubaque
# Processing Record 13 of Set 7 | bukama
# Processing Record 14 of Set 7 | aripuana
# Processing Record 15 of Set 7 | muros
# Processing Record 16 of Set 7 | chunskiy
# Processing Record 17 of Set 7 | strezhevoy
# Processing Record 18 of Set 7 | wahran
# City not found. Skipping...
# Processing Record 19 of Set 7 | college
# Processing Record 20 of Set 7 | portland
# Processing Record 21 of Set 7 | hami
# Processing Record 22 of Set 7 | riverton
# Processing Record 23 of Set 7 | minab
# Processing Record 24 of Set 7 | kenitra
# Processing Record 25 of Set 7 | burica
# City not found. Skipping...
# Processing Record 26 of Set 7 | yar-sale
# Processing Record 27 of Set 7 | tomatlan
# Processing Record 28 of Set 7 | zhezkazgan
# Processing Record 29 of Set 7 | jumla
# Processing Record 30 of Set 7 | panalingaan
# Processing Record 31 of Set 7 | sangar
# Processing Record 32 of Set 7 | petropavlivka
# Processing Record 33 of Set 7 | luderitz
# Processing Record 34 of Set 7 | acajutla
# Processing Record 35 of Set 7 | gurskoye
# City not found. Skipping...
# Processing Record 36 of Set 7 | sabha
# Processing Record 37 of Set 7 | zolotinka
# City not found. Skipping...
# Processing Record 38 of Set 7 | codrington
# Processing Record 39 of Set 7 | scarborough
# Processing Record 40 of Set 7 | mansfield
# Processing Record 41 of Set 7 | kahului
# Processing Record 42 of Set 7 | severobaykalsk
# Processing Record 43 of Set 7 | nanortalik
# Processing Record 44 of Set 7 | cockburn town
# Processing Record 45 of Set 7 | emerald
# Processing Record 46 of Set 7 | tiznit
# Processing Record 47 of Set 7 | komsomolskiy
# Processing Record 48 of Set 7 | akyab
# Processing Record 49 of Set 7 | imbituba
# Processing Record 50 of Set 7 | ningxiang
# Processing Record 1 of Set 8 | airai
# Processing Record 2 of Set 8 | solhan
# Processing Record 3 of Set 8 | dudinka
# Processing Record 4 of Set 8 | vicuna
# Processing Record 5 of Set 8 | xining
# Processing Record 6 of Set 8 | himora
# City not found. Skipping...
# Processing Record 7 of Set 8 | caetes
# Processing Record 8 of Set 8 | gannan
# Processing Record 9 of Set 8 | buraydah
# Processing Record 10 of Set 8 | hervey bay
# Processing Record 11 of Set 8 | zhanatas
# City not found. Skipping...
# Processing Record 12 of Set 8 | kavieng
# Processing Record 13 of Set 8 | san ignacio de sabaneta
# City not found. Skipping...
# Processing Record 14 of Set 8 | coari
# Processing Record 15 of Set 8 | atbasar
# Processing Record 16 of Set 8 | nicoya
# Processing Record 17 of Set 8 | canavieiras
# Processing Record 18 of Set 8 | tashtyp
# Processing Record 19 of Set 8 | batticaloa
# Processing Record 20 of Set 8 | huilong
# Processing Record 21 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 22 of Set 8 | batagay-alyta
# Processing Record 23 of Set 8 | usevya
# Processing Record 24 of Set 8 | cananeia
# Processing Record 25 of Set 8 | dmitriyevka
# Processing Record 26 of Set 8 | bahia blanca
# Processing Record 27 of Set 8 | vardo
# Processing Record 28 of Set 8 | sandpoint
# Processing Record 29 of Set 8 | rorvik
# Processing Record 30 of Set 8 | haines junction
# Processing Record 31 of Set 8 | oistins
# Processing Record 32 of Set 8 | taikang
# Processing Record 33 of Set 8 | chake chake
# Processing Record 34 of Set 8 | hirara
# Processing Record 35 of Set 8 | geraldton
# Processing Record 36 of Set 8 | kampot
# Processing Record 37 of Set 8 | fehervarcsurgo
# Processing Record 38 of Set 8 | gravdal
# Processing Record 39 of Set 8 | santa maria
# Processing Record 40 of Set 8 | outjo
# Processing Record 41 of Set 8 | mana
# Processing Record 42 of Set 8 | bodden town
# Processing Record 43 of Set 8 | san policarpo
# Processing Record 44 of Set 8 | jinchengjiang
# City not found. Skipping...
# Processing Record 45 of Set 8 | agustin codazzi
# Processing Record 46 of Set 8 | san rafael
# Processing Record 47 of Set 8 | obidos
# Processing Record 48 of Set 8 | salinopolis
# Processing Record 49 of Set 8 | aswan
# Processing Record 50 of Set 8 | suntar
# Processing Record 1 of Set 9 | flic en flac
# Processing Record 2 of Set 9 | tornio
# Processing Record 3 of Set 9 | port moresby
# Processing Record 4 of Set 9 | hulan ergi
# Processing Record 5 of Set 9 | nemuro
# Processing Record 6 of Set 9 | bandundu
# Processing Record 7 of Set 9 | vao
# Processing Record 8 of Set 9 | beira
# Processing Record 9 of Set 9 | dargaville
# Processing Record 10 of Set 9 | labuhan
# Processing Record 11 of Set 9 | bosaso
# Processing Record 12 of Set 9 | ilulissat
# Processing Record 13 of Set 9 | atar
# Processing Record 14 of Set 9 | pacific grove
# Processing Record 15 of Set 9 | safaqis
# City not found. Skipping...
# Processing Record 16 of Set 9 | tacoronte
# Processing Record 17 of Set 9 | hofn
# Processing Record 18 of Set 9 | vila franca do campo
# Processing Record 19 of Set 9 | satitoa
# City not found. Skipping...
# Processing Record 20 of Set 9 | ojinaga
# Processing Record 21 of Set 9 | faanui
# Processing Record 22 of Set 9 | bustonkala
# City not found. Skipping...
# Processing Record 23 of Set 9 | vestmanna
# Processing Record 24 of Set 9 | carauari
# Processing Record 25 of Set 9 | kelso
# Processing Record 26 of Set 9 | san cristobal
# Processing Record 27 of Set 9 | filingue
# Processing Record 28 of Set 9 | caetite
# Processing Record 29 of Set 9 | deer lake
# Processing Record 30 of Set 9 | sao filipe
# Processing Record 31 of Set 9 | magadan
# Processing Record 32 of Set 9 | buenos aires
# Processing Record 33 of Set 9 | verkhnya syrovatka
# Processing Record 34 of Set 9 | iqaluit
# Processing Record 35 of Set 9 | sumy
# Processing Record 36 of Set 9 | indramayu
# Processing Record 37 of Set 9 | mtwara
# Processing Record 38 of Set 9 | hastings
# Processing Record 39 of Set 9 | mayuge
# Processing Record 40 of Set 9 | zacualpan
# Processing Record 41 of Set 9 | segou
# Processing Record 42 of Set 9 | bad berleburg
# Processing Record 43 of Set 9 | bokovskaya
# Processing Record 44 of Set 9 | santa rosa
# Processing Record 45 of Set 9 | marzuq
# Processing Record 46 of Set 9 | tierralta
# Processing Record 47 of Set 9 | trapani
# Processing Record 48 of Set 9 | rafsanjan
# Processing Record 49 of Set 9 | dzhusaly
# City not found. Skipping...
# Processing Record 50 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 1 of Set 10 | waipawa
# Processing Record 2 of Set 10 | umm kaddadah
# Processing Record 3 of Set 10 | invermere
# Processing Record 4 of Set 10 | pithoragarh
# Processing Record 5 of Set 10 | san isidro
# Processing Record 6 of Set 10 | dawei
# Processing Record 7 of Set 10 | iguape
# Processing Record 8 of Set 10 | marrakesh
# Processing Record 9 of Set 10 | brae
# Processing Record 10 of Set 10 | aykhal
# Processing Record 11 of Set 10 | standerton
# Processing Record 12 of Set 10 | surazh
# Processing Record 13 of Set 10 | beroroha
# Processing Record 14 of Set 10 | namatanai
# Processing Record 15 of Set 10 | biak
# Processing Record 16 of Set 10 | shubarshi
# Processing Record 17 of Set 10 | aras
# Processing Record 18 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 19 of Set 10 | bucerias
# Processing Record 20 of Set 10 | morogoro
# Processing Record 21 of Set 10 | havoysund
# Processing Record 22 of Set 10 | mnogovershinnyy
# Processing Record 23 of Set 10 | taltal
# Processing Record 24 of Set 10 | koslan
# Processing Record 25 of Set 10 | kavaratti
# Processing Record 26 of Set 10 | eyl
# Processing Record 27 of Set 10 | powell river
# Processing Record 28 of Set 10 | mweka
# Processing Record 29 of Set 10 | requena
# Processing Record 30 of Set 10 | opuwo
# Processing Record 31 of Set 10 | port-gentil
# Processing Record 32 of Set 10 | oda
# Processing Record 33 of Set 10 | kimbe
# Processing Record 34 of Set 10 | sungaipenuh
# Processing Record 35 of Set 10 | butembo
# Processing Record 36 of Set 10 | zyryanka
# Processing Record 37 of Set 10 | cidreira
# Processing Record 38 of Set 10 | freeport
# Processing Record 39 of Set 10 | sao joao da barra
# Processing Record 40 of Set 10 | fuling
# Processing Record 41 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 42 of Set 10 | cozumel
# Processing Record 43 of Set 10 | havelock
# Processing Record 44 of Set 10 | tabou
# Processing Record 45 of Set 10 | saurimo
# Processing Record 46 of Set 10 | kirkwall
# Processing Record 47 of Set 10 | akhisar
# Processing Record 48 of Set 10 | oyon
# Processing Record 49 of Set 10 | porto belo
# Processing Record 50 of Set 10 | tambura
# Processing Record 1 of Set 11 | srednekolymsk
# Processing Record 2 of Set 11 | palora
# Processing Record 3 of Set 11 | bongandanga
# Processing Record 4 of Set 11 | kawalu
# Processing Record 5 of Set 11 | buala
# Processing Record 6 of Set 11 | viedma
# Processing Record 7 of Set 11 | roma
# Processing Record 8 of Set 11 | carlsbad
# Processing Record 9 of Set 11 | masuri
# Processing Record 10 of Set 11 | iskateley
# Processing Record 11 of Set 11 | ghogha
# Processing Record 12 of Set 11 | pinar del rio
# Processing Record 13 of Set 11 | lethem
# Processing Record 14 of Set 11 | kumano
# Processing Record 15 of Set 11 | contai
# Processing Record 16 of Set 11 | las palmas
# Processing Record 17 of Set 11 | preobrazheniye
# Processing Record 18 of Set 11 | karkaralinsk
# City not found. Skipping...
# Processing Record 19 of Set 11 | sao raimundo nonato
# Processing Record 20 of Set 11 | leh
# Processing Record 21 of Set 11 | quatre cocos
# Processing Record 22 of Set 11 | marawi
# Processing Record 23 of Set 11 | nouadhibou
# Processing Record 24 of Set 11 | dunedin
# Processing Record 25 of Set 11 | bathsheba
# Processing Record 26 of Set 11 | sunbury
# Processing Record 27 of Set 11 | bitkine
# Processing Record 28 of Set 11 | necochea
# Processing Record 29 of Set 11 | nanma
# Processing Record 30 of Set 11 | platanos
# Processing Record 31 of Set 11 | hay river
# Processing Record 32 of Set 11 | makokou
# Processing Record 33 of Set 11 | torbay
# Processing Record 34 of Set 11 | fevralsk
# City not found. Skipping...
# Processing Record 35 of Set 11 | rawson
# Processing Record 36 of Set 11 | katherine
# Processing Record 37 of Set 11 | gazanjyk
# Processing Record 38 of Set 11 | yaan
# Processing Record 39 of Set 11 | mutsamudu
# City not found. Skipping...
# Processing Record 40 of Set 11 | bay roberts
# Processing Record 41 of Set 11 | saint-francois
# Processing Record 42 of Set 11 | vestmannaeyjar
# Processing Record 43 of Set 11 | maxixe
# Processing Record 44 of Set 11 | bombay
# Processing Record 45 of Set 11 | eureka
# Processing Record 46 of Set 11 | dosso
# Processing Record 47 of Set 11 | koumra
# Processing Record 48 of Set 11 | okhotsk
# Processing Record 49 of Set 11 | guilin
# Processing Record 50 of Set 11 | ongandjera
# Processing Record 1 of Set 12 | plettenberg bay
# Processing Record 2 of Set 12 | paamiut
# Processing Record 3 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 4 of Set 12 | irricana
# Processing Record 5 of Set 12 | yuzhno-kurilsk
# Processing Record 6 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 7 of Set 12 | lancaster
# Processing Record 8 of Set 12 | seoul
# Processing Record 9 of Set 12 | nishihara
# Processing Record 10 of Set 12 | igarka
# Processing Record 11 of Set 12 | bastrop
# Processing Record 12 of Set 12 | flin flon
# Processing Record 13 of Set 12 | jinxiang
# Processing Record 14 of Set 12 | swellendam
# Processing Record 15 of Set 12 | lompoc
# Processing Record 16 of Set 12 | guaimaca
# Processing Record 17 of Set 12 | blonduos
# City not found. Skipping...
# Processing Record 18 of Set 12 | takaungu
# Processing Record 19 of Set 12 | davila
# Processing Record 20 of Set 12 | santa fe
# Processing Record 21 of Set 12 | high rock
# Processing Record 22 of Set 12 | oksfjord
# Processing Record 23 of Set 12 | castelo
# Processing Record 24 of Set 12 | karamea
# City not found. Skipping...
# Processing Record 25 of Set 12 | nhulunbuy
# Processing Record 26 of Set 12 | kushiro
# Processing Record 27 of Set 12 | san buenaventura
# Processing Record 28 of Set 12 | lokosovo
# Processing Record 29 of Set 12 | kamenka
# Processing Record 30 of Set 12 | trani
# Processing Record 31 of Set 12 | port macquarie
# Processing Record 32 of Set 12 | kaeo
# Processing Record 33 of Set 12 | mayumba
# Processing Record 34 of Set 12 | san benito
# Processing Record 35 of Set 12 | great bend
# Processing Record 36 of Set 12 | qandala
# Processing Record 37 of Set 12 | conde
# Processing Record 38 of Set 12 | henties bay
# Processing Record 39 of Set 12 | lagoa
# Processing Record 40 of Set 12 | norman wells
# Processing Record 41 of Set 12 | stawell
# Processing Record 42 of Set 12 | tura
# Processing Record 43 of Set 12 | jalu
# Processing Record 44 of Set 12 | rabak
# Processing Record 45 of Set 12 | valparaiso
# Processing Record 46 of Set 12 | maragogi
# Processing Record 47 of Set 12 | vostok
# Processing Record 48 of Set 12 | matara
# Processing Record 49 of Set 12 | caldwell
# Processing Record 50 of Set 12 | douglas
# Processing Record 1 of Set 13 | gazli
# Processing Record 2 of Set 13 | neyshabur
# Processing Record 3 of Set 13 | dergachi
# Processing Record 4 of Set 13 | inhambane
# Processing Record 5 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 6 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 7 of Set 13 | poum
# Processing Record 8 of Set 13 | yatou
# Processing Record 9 of Set 13 | ahumada
# City not found. Skipping...
# Processing Record 10 of Set 13 | labuan
# Processing Record 11 of Set 13 | grenville
# Processing Record 12 of Set 13 | pointe michel
# Processing Record 13 of Set 13 | asau
# Processing Record 14 of Set 13 | alice springs
# Processing Record 15 of Set 13 | luanda
# Processing Record 16 of Set 13 | fort nelson
# Processing Record 17 of Set 13 | vieques
# Processing Record 18 of Set 13 | chifeng
# Processing Record 19 of Set 13 | javornik
# Processing Record 20 of Set 13 | belogradcik
# City not found. Skipping...
# Processing Record 21 of Set 13 | oum hadjer
# Processing Record 22 of Set 13 | los llanos de aridane
# Processing Record 23 of Set 13 | awjilah
# Processing Record 24 of Set 13 | bozhou
# Processing Record 25 of Set 13 | sitka
# Processing Record 26 of Set 13 | sikonge
# Processing Record 27 of Set 13 | kentau
# Processing Record 28 of Set 13 | sipe sipe
# Processing Record 29 of Set 13 | la ronge
# Processing Record 30 of Set 13 | neiafu
# Processing Record 31 of Set 13 | kintampo
# Processing Record 32 of Set 13 | garissa
# Processing Record 33 of Set 13 | misratah
# Processing Record 34 of Set 13 | kande
# Processing Record 35 of Set 13 | samarai
# Processing Record 36 of Set 13 | prince rupert
# Processing Record 37 of Set 13 | yerbogachen
# Processing Record 38 of Set 13 | nikki
# Processing Record 39 of Set 13 | nyrob
# Processing Record 40 of Set 13 | broome
# Processing Record 41 of Set 13 | goderich
# Processing Record 42 of Set 13 | campina verde
# Processing Record 43 of Set 13 | mme
# City not found. Skipping...
# Processing Record 44 of Set 13 | yayva
# Processing Record 45 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 46 of Set 13 | eston
# Processing Record 47 of Set 13 | lenine
# Processing Record 48 of Set 13 | porbandar
# Processing Record 49 of Set 13 | vila do maio
# Processing Record 50 of Set 13 | dhangadhi
# Processing Record 1 of Set 14 | shahrud
# Processing Record 2 of Set 14 | siuna
# Processing Record 3 of Set 14 | abu samrah
# Processing Record 4 of Set 14 | mehamn
# Processing Record 5 of Set 14 | kjollefjord
# Processing Record 6 of Set 14 | nome
# Processing Record 7 of Set 14 | golden
# Processing Record 8 of Set 14 | rio grande
# Processing Record 9 of Set 14 | cascais
# Processing Record 10 of Set 14 | faya
# Processing Record 11 of Set 14 | djougou
# Processing Record 12 of Set 14 | taft
# Processing Record 13 of Set 14 | alta floresta
# Processing Record 14 of Set 14 | ottawa
# Processing Record 15 of Set 14 | lodja
# Processing Record 16 of Set 14 | rawannawi
# City not found. Skipping...
# Processing Record 17 of Set 14 | vredendal
# Processing Record 18 of Set 14 | cambe
# Processing Record 19 of Set 14 | half moon bay
# Processing Record 20 of Set 14 | ranong
# Processing Record 21 of Set 14 | kasra
# City not found. Skipping...
# Processing Record 22 of Set 14 | solnechnyy
# Processing Record 23 of Set 14 | rengasdengklok
# Processing Record 24 of Set 14 | bardiyah
# Processing Record 25 of Set 14 | kamaishi
# Processing Record 26 of Set 14 | kiama
# Processing Record 27 of Set 14 | lazaro cardenas
# Processing Record 28 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 29 of Set 14 | tala
# Processing Record 30 of Set 14 | kiruna
# Processing Record 31 of Set 14 | azimur
# City not found. Skipping...
# Processing Record 32 of Set 14 | sur
# Processing Record 33 of Set 14 | moron
# Processing Record 34 of Set 14 | severo-yeniseyskiy
# Processing Record 35 of Set 14 | santa luzia
# Processing Record 36 of Set 14 | barra patuca
# Processing Record 37 of Set 14 | padang
# Processing Record 38 of Set 14 | murindo
# Processing Record 39 of Set 14 | ulaanbaatar
# Processing Record 40 of Set 14 | tanout
# Processing Record 41 of Set 14 | winnemucca
# Processing Record 42 of Set 14 | whyalla
# Processing Record 43 of Set 14 | mirnyy
# Processing Record 44 of Set 14 | katobu
# Processing Record 45 of Set 14 | chikoy
# City not found. Skipping...
# Processing Record 46 of Set 14 | eyrarbakki
# Processing Record 47 of Set 14 | nan
# Processing Record 48 of Set 14 | totskoye
# Processing Record 49 of Set 14 | belmonte
# Processing Record 50 of Set 14 | cape coast
# Processing Record 1 of Set 15 | verkhnyaya inta
# Processing Record 2 of Set 15 | arkhangelskoye
# Processing Record 3 of Set 15 | macau
# Processing Record 4 of Set 15 | birao
# Processing Record 5 of Set 15 | shimoda
# Processing Record 6 of Set 15 | luebo
# Processing Record 7 of Set 15 | berbera
# Processing Record 8 of Set 15 | oranjemund
# Processing Record 9 of Set 15 | joaquim nabuco
# Processing Record 10 of Set 15 | sri aman
# Processing Record 11 of Set 15 | corinto
# Processing Record 12 of Set 15 | fare
# Processing Record 13 of Set 15 | kaihua
# Processing Record 14 of Set 15 | princeton
# Processing Record 15 of Set 15 | palestine
# Processing Record 16 of Set 15 | aguada de pasajeros
# Processing Record 17 of Set 15 | korem
# Processing Record 18 of Set 15 | malwan
# City not found. Skipping...
# Processing Record 19 of Set 15 | cabadiangan
# Processing Record 20 of Set 15 | cavalcante
# Processing Record 21 of Set 15 | ixtapa
# Processing Record 22 of Set 15 | sumbawa
# City not found. Skipping...
# Processing Record 23 of Set 15 | anloga
# Processing Record 24 of Set 15 | banff
# Processing Record 25 of Set 15 | luba
# Processing Record 26 of Set 15 | koster
# Processing Record 27 of Set 15 | yarmouth
# Processing Record 28 of Set 15 | gyoda
# Processing Record 29 of Set 15 | estevan
# Processing Record 30 of Set 15 | talnakh
# Processing Record 31 of Set 15 | ayolas
# Processing Record 32 of Set 15 | tilichiki
# Processing Record 33 of Set 15 | robertsport
# Processing Record 34 of Set 15 | belaya gora
# Processing Record 35 of Set 15 | deputatskiy
# Processing Record 36 of Set 15 | baykit
# Processing Record 37 of Set 15 | nawa
# Processing Record 38 of Set 15 | albury
# Processing Record 39 of Set 15 | berlevag
# Processing Record 40 of Set 15 | tobane
# Processing Record 41 of Set 15 | nadym
# Processing Record 42 of Set 15 | longlac
# City not found. Skipping...
# Processing Record 43 of Set 15 | aranos
# Processing Record 44 of Set 15 | hihifo
# City not found. Skipping...
# Processing Record 45 of Set 15 | elizabeth city
# Processing Record 46 of Set 15 | forli
# Processing Record 47 of Set 15 | olden
# Processing Record 48 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 49 of Set 15 | bethal
# Processing Record 50 of Set 15 | sijunjung
# Processing Record 1 of Set 16 | poya
# Processing Record 2 of Set 16 | gogrial
# Processing Record 3 of Set 16 | nyazepetrovsk
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0          Ushuaia      AR -54.8000 -68.3000     38.86        81          40
# 1          Salalah      OM  17.0151  54.0924     78.89        34           0
# 2   Port Elizabeth      ZA -33.9180  25.5701     65.10        97          75
# 3         Barranca      PE -10.7500 -77.7667     67.21        88          77
# 4          Veraval      IN  20.9000  70.3667     85.33        48           9
# 5  Arraial Do Cabo      BR -22.9661 -42.0278     76.23        87          98
# 6     Punta Arenas      CL -53.1500 -70.9167     44.71        76           0
# 7        Upernavik      GL  72.7868 -56.1549      7.14        96          92
# 8        Mogadishu      SO   2.0371  45.3438     82.27        78          75
# 9        Springbok      ZA -29.6643  17.8865     52.25        75          94
#
#    Wind Speed Weather Description
# 0        4.61    scattered clouds
# 1        2.30           clear sky
# 2       10.36       moderate rain
# 3        6.91       broken clouds
# 4        4.29           clear sky
# 5        7.61     overcast clouds
# 6       23.02           clear sky
# 7       10.94     overcast clouds
# 8       10.36       broken clouds
# 9        0.74     overcast clouds

# %%
city_data_df = city_data_df[['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Weather Description']]
city_data_df
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0           Ushuaia      AR -54.8000  -68.3000     38.86        81
# 1           Salalah      OM  17.0151   54.0924     78.89        34
# 2    Port Elizabeth      ZA -33.9180   25.5701     65.10        97
# 3          Barranca      PE -10.7500  -77.7667     67.21        88
# 4           Veraval      IN  20.9000   70.3667     85.33        48
# ..              ...     ...      ...       ...       ...       ...
# 680          Bethal      ZA -26.4579   29.4655     54.55        78
# 681       Sijunjung      ID  -0.6876  100.9537     94.10        33
# 682            Poya      NC -21.3500  165.1500     84.16        78
# 683         Gogrial      SS   8.5332   28.1004     85.37        41
# 684   Nyazepetrovsk      RU  56.0531   59.6028     35.87       100
#
#      Cloudiness  Wind Speed Weather Description
# 0            40        4.61    scattered clouds
# 1             0        2.30           clear sky
# 2            75       10.36       moderate rain
# 3            77        6.91       broken clouds
# 4             9        4.29           clear sky
# ..          ...         ...                 ...
# 680          41        5.50    scattered clouds
# 681          30        3.06    scattered clouds
# 682          85       10.04     overcast clouds
# 683          98        3.49     overcast clouds
# 684         100        4.56     overcast clouds
#
# [685 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
